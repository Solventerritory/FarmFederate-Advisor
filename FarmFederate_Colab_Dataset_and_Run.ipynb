# %% [markdown]
# # FarmFederate — Colab Notebook
#
# This notebook helps you run the FarmFederate pipeline in Colab. It contains safe preview (dry-run), dataset acquisition, dataset checking, and training steps. **No cell will be executed automatically**; follow the cells step-by-step and provide credentials where needed.

# %% [markdown]
# ## 1) Colab setup & dependencies ⚙️
#
# This cell installs needed packages and shows common setup steps. Run it once after creating a new Colab runtime.

# %%
```bash
# Install core packages (use a single cell in Colab)
python -m pip install --upgrade pip
pip install -r requirements.txt || true
pip install kaggle datasets transformers accelerate --upgrade
# Optional: pillow-simd for faster image processing
# pip install -U pillow-simd
```

# %% [markdown]
# ## 2) Credentials (Kaggle & HuggingFace)
#
# - Upload your `kaggle.json` (from https://www.kaggle.com/me/account) to Colab and move it to `~/.kaggle/kaggle.json` with `chmod 600`.
# - Set HuggingFace token in an env var `HF_TOKEN` (recommended) or use the login helper below.

# %%
# Upload kaggle.json and set it up (one-time)
from google.colab import files
print('Upload kaggle.json when prompted (https://www.kaggle.com/me/account)')
uploaded = files.upload()
if 'kaggle.json' in uploaded:
    import os
    os.makedirs('/root/.kaggle', exist_ok=True)
    open('/root/.kaggle/kaggle.json','wb').write(uploaded['kaggle.json'])
    os.chmod('/root/.kaggle/kaggle.json', 0o600)
    print('kaggle.json saved to /root/.kaggle/kaggle.json')
else:
    print('kaggle.json not uploaded; you can still use HTTP/GitHub fallbacks')

# Set HF token interactively (recommended)
try:
    hf = input('Paste your HuggingFace token (or leave blank to skip): ').strip()
    if hf:
        import os
        os.environ['HF_TOKEN'] = hf
        print('HF_TOKEN set in environment for this session')
except Exception as e:
    print('Skipping HF token setup:', e)

# %% [markdown]
# ## 3) Verify tests & local utilities ✅
#
# Quick smoke tests to ensure helper modules are importable and local tests pass.

# %%
# Run tests (pytest) - this will not run long tests, only unit tests added to repo
# !pytest -q tests/test_dataset_utils.py -q || true

# Try importing dataset utilities to check for obvious import errors
try:
    from dataset_utils import build_text_label_dfs, count_images_in_dir
    print('dataset_utils imported successfully')
except Exception as e:
    print('Import failed:', e)

# %% [markdown]
# ## 4) Dry-run (preview datasets) 🔍
#
# Run the script with dry-run & report-only flags to inspect what would be downloaded/discovered. This is the recommended first step.

# %%
# Preview (no network actions if --dry-run is implemented in script)
# !python FarmFederate_Kaggle_Complete.py --dry-run --report-only

# After running, inspect generated reports
import json, os
if os.path.exists('datasets_report.json'):
    print('datasets_report.json found — preview:')
    print(json.dumps(json.load(open('datasets_report.json')), indent=2)[:1000])
else:
    print('datasets_report.json not found — check script output or logs')
# Out:
# [*] Using device: cpu
#
# ======================================================================
# CONFIGURATION
# ======================================================================
# Labels: ['water_stress', 'nutrient_def', 'pest_risk', 'disease_risk', 'heat_stress']
# Config: {
#   "max_samples": 600,
#   "train_split": 0.8,
#   "batch_size": 8,
#   "text_embed_dim": 256,
#   "vision_embed_dim": 256,
#   "hidden_dim": 256,
#   "num_labels": 5,
#   "epochs": 5,
#   "learning_rate": 0.0002,
#   "weight_decay": 0.01,
#   "num_clients": 3,
#   "fed_rounds": 3,
#   "local_epochs": 2,
#   "dirichlet_alpha": 0.5,
#   "participation_rate": 0.8,
#   "fusion_types": [
#     "concat",
#     "attention",
#     "gated",
#     "clip",
#     "flamingo",
#     "blip2",
#     "coca",
#     "unified_io"
#   ],
#   "seed": 42
# }
#
# ======================================================================
# DATA GENERATION
# ======================================================================
# == Checking candidates for label: water_stress ==
# Trying HTTP download: https://github.com/ashokpant/drought-detection
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection -> drought
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/drought-detection/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/releases/latest/download/asset.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ashokpant/drought-detection
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection -> drought
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/drought-detection/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/releases/latest/download/asset.zip -> drought
# Attempting git clone of https://github.com/ashokpant/drought-detection.git
# git clone failed: Cloning into 'drought'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ashokpant/drought-detection.git/' not found
#
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip -> drought
# Attempting git clone of https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'drought'...
# remote: Not Found
# fatal: repository 'https://github.com/ashokpant/drought-detection/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip -> drought
# Attempting git clone of https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'drought'...
# remote: Not Found
# fatal: repository 'https://github.com/ashokpant/drought-detection/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection -> drought
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/releases/latest/download/asset.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection -> drought
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip -> drought
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/releases/latest/download/asset.zip -> drought
# Attempting git clone of https://github.com/ashokpant/DroughtDetection.git
# git clone failed: Cloning into 'drought'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ashokpant/DroughtDetection.git/' not found
#
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip -> drought
# Attempting git clone of https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'drought'...
# remote: Not Found
# fatal: repository 'https://github.com/ashokpant/DroughtDetection/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip -> drought
# Attempting git clone of https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'drought'...
# remote: Not Found
# fatal: repository 'https://github.com/ashokpant/DroughtDetection/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/tomkelly110/Seedlings
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings -> drought
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip -> drought
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip -> drought
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/releases/latest/download/asset.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/tomkelly110/Seedlings
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings -> drought
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip -> drought
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip -> drought
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/releases/latest/download/asset.zip -> drought
# Attempting git clone of https://github.com/tomkelly110/Seedlings.git
# git clone succeeded
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip -> drought
# Attempting git clone of https://github.com/tomkelly110/Seedlings/archive/refs/heads/main.zip.git
# git clone failed: fatal: destination path 'drought' already exists and is not an empty directory.
#
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip -> drought
# Attempting git clone of https://github.com/tomkelly110/Seedlings/archive/refs/heads/master.zip.git
# git clone failed: fatal: destination path 'drought' already exists and is not an empty directory.
#
# Trying HTTP download: https://www.kaggle.com/datasets/ashokpant/drought-detection
# [DRY_RUN] Would download https://www.kaggle.com/datasets/ashokpant/drought-detection -> drought
# Retrying HTTP downloads...
# Trying HTTP download: https://www.kaggle.com/datasets/ashokpant/drought-detection
# [DRY_RUN] Would download https://www.kaggle.com/datasets/ashokpant/drought-detection -> drought
# No dataset found for label water_stress from candidates ['Drought_Detection'].
# == Checking candidates for label: nutrient_def ==
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/releases/latest/download/asset.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/releases/latest/download/asset.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/plantdoc-dataset.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Repository not found.
# fatal: repository 'https://github.com/pratik2901/plantdoc-dataset.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Not Found
# fatal: repository 'https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Not Found
# fatal: repository 'https://github.com/pratik2901/plantdoc-dataset/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/PlantDoc
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/releases/latest/download/asset.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/PlantDoc
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/releases/latest/download/asset.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/PlantDoc.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Repository not found.
# fatal: repository 'https://github.com/pratik2901/PlantDoc.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Not Found
# fatal: repository 'https://github.com/pratik2901/PlantDoc/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Not Found
# fatal: repository 'https://github.com/pratik2901/PlantDoc/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/releases/latest/download/asset.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip -> plantdoc
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/releases/latest/download/asset.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/PlantDoc-Dataset.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Repository not found.
# fatal: repository 'https://github.com/pratik2901/PlantDoc-Dataset.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Not Found
# fatal: repository 'https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip -> plantdoc
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip -> plantdoc
# Attempting git clone of https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'plantdoc'...
# remote: Not Found
# fatal: repository 'https://github.com/pratik2901/PlantDoc-Dataset/archive/refs/heads/master.zip.git/' not found
#
# No dataset found for label nutrient_def from candidates ['PlantDoc'].
# == Checking candidates for label: pest_risk ==
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102 -> ip102
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/releases/latest/download/asset.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102 -> ip102
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/releases/latest/download/asset.zip -> ip102
# Attempting git clone of https://github.com/PKU-ICST-MIPL/IP102.git
# git clone failed: Cloning into 'ip102'...
# remote: Repository not found.
# fatal: repository 'https://github.com/PKU-ICST-MIPL/IP102.git/' not found
#
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Attempting git clone of https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'ip102'...
# remote: Not Found
# fatal: repository 'https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Attempting git clone of https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'ip102'...
# remote: Not Found
# fatal: repository 'https://github.com/PKU-ICST-MIPL/IP102/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/ICST-MIPL/IP102
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102 -> ip102
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/releases/latest/download/asset.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ICST-MIPL/IP102
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102 -> ip102
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/releases/latest/download/asset.zip -> ip102
# Attempting git clone of https://github.com/ICST-MIPL/IP102.git
# git clone failed: Cloning into 'ip102'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ICST-MIPL/IP102.git/' not found
#
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip -> ip102
# Attempting git clone of https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'ip102'...
# remote: Not Found
# fatal: repository 'https://github.com/ICST-MIPL/IP102/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip -> ip102
# Attempting git clone of https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'ip102'...
# remote: Not Found
# fatal: repository 'https://github.com/ICST-MIPL/IP102/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets -> ip102
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip -> ip102
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip -> ip102
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/releases/latest/download/asset.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets -> ip102
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip -> ip102
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip -> ip102
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/releases/latest/download/asset.zip -> ip102
# Attempting git clone of https://github.com/sohailjawed/IP-disease-detection-datasets.git
# git clone failed: Cloning into 'ip102'...
# remote: Repository not found.
# fatal: repository 'https://github.com/sohailjawed/IP-disease-detection-datasets.git/' not found
#
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip -> ip102
# Attempting git clone of https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'ip102'...
# remote: Not Found
# fatal: repository 'https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip -> ip102
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip -> ip102
# Attempting git clone of https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'ip102'...
# remote: Not Found
# fatal: repository 'https://github.com/sohailjawed/IP-disease-detection-datasets/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip -> plant_seedlings
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip -> plant_seedlings
# Attempting git clone of https://github.com/kmader/plant-seedlings-classification.git
# git clone failed: Cloning into 'plant_seedlings'...
# remote: Repository not found.
# fatal: repository 'https://github.com/kmader/plant-seedlings-classification.git/' not found
#
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Attempting git clone of https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'plant_seedlings'...
# remote: Not Found
# fatal: repository 'https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Attempting git clone of https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'plant_seedlings'...
# remote: Not Found
# fatal: repository 'https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip.git/' not found
#
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip -> plant_seedlings
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/releases/latest/download/asset.zip -> plant_seedlings
# Attempting git clone of https://github.com/kmader/plant-seedlings-classification.git
# git clone failed: Cloning into 'plant_seedlings'...
# remote: Repository not found.
# fatal: repository 'https://github.com/kmader/plant-seedlings-classification.git/' not found
#
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip -> plant_seedlings
# Attempting git clone of https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip.git
# git clone failed: Cloning into 'plant_seedlings'...
# remote: Not Found
# fatal: repository 'https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/main.zip.git/' not found
#
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Retrying HTTP downloads...
# Trying HTTP download: https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip
# [DRY_RUN] Would download https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip -> plant_seedlings
# Attempting git clone of https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip.git
# git clone failed: Cloning into 'plant_seedlings'...
# remote: Not Found
# fatal: repository 'https://github.com/kmader/plant-seedlings-classification/archive/refs/heads/master.zip.git/' not found
#
# No dataset found for label pest_risk from candidates ['IP102', 'Plant_Seedlings'].
# == Checking candidates for label: disease_risk ==
# No dataset found for label disease_risk from candidates ['PlantVillage', 'Plant_Pathology', 'Crop_Disease'].
# == Checking candidates for label: heat_stress ==
# No dataset found for label heat_stress from candidates ['Crop_Disease'].
# Missing label datasets: ['water_stress', 'nutrient_def', 'pest_risk', 'disease_risk', 'heat_stress']
#
# ERROR: Missing real datasets for required labels and --allow-synthesis not set.
#
# To resolve:
#   1) Provide Kaggle credentials and accept any required competitions (see https://www.kaggle.com).
#   2) Place dataset folders manually under expected paths (e.g., plantdoc/, ip102/, drought/).
#   3) Add working mirror URLs to FALLBACK_SOURCES in the script or rerun with --allow-synthesis to allow synthesized fallbacks.
# Wrote download_instructions.sh with suggested Kaggle commands
# Wrote datasets_report.json with missing_labels and provenance. Exiting so real datasets can be provided.
# datasets_report.json found — preview:
# {
#   "status": "missing_real_datasets",
#   "missing_labels": [
#     "water_stress",
#     "nutrient_def",
#     "pest_risk",
#     "disease_risk",
#     "heat_stress"
#   ],
#   "found_label_provenance": {},
#   "image_label_roots": {}
# }

# %% [markdown]
# ## 5) Download datasets (Kaggle & HTTP fallbacks) ⬇️
#
# If the dry-run preview looks good, run download-only. Ensure `~/.kaggle/kaggle.json` is present and you have accepted competitions when required.

# %%
# Download (may take a long time depending on datasets and your connection)
# !python FarmFederate_Kaggle_Complete.py --download-only

# After download, run the local scanner to verify
# !python scripts/check_datasets.py || true

# Preview local report if created
import json, os
if os.path.exists('local_datasets_report.json'):
    print(json.dumps(json.load(open('local_datasets_report.json')), indent=2)[:1000])
else:
    print('local_datasets_report.json not found — check check_datasets.py output')

# %% [markdown]
# ## 6) Quick smoke training (small run) 🏃‍♂️
#
# To test the end-to-end training quickly, set small sample/epoch parameters in the script or use environment overrides if available. This avoids long runs during initial validation.
#
# **Example:** set small environment var and run training (the script must honor these env vars or you can edit config in the script):

# %%
# Example of running a quick training (modify script to accept QUICK_TRAIN or set config vars inside it)
# This example assumes the script respects QUICK_TRAIN env var to limit data and epochs.
import os
os.environ['QUICK_TRAIN'] = '1'
# Run a short test training — expect it to finish quickly (e.g., 1 epoch, few samples)
# !python FarmFederate_Kaggle_Complete.py --train-quick || true

# %% [markdown]
# ## 7) Inspect dataset report & visualize samples 📊
#
# Load the `datasets_report.json` and show label counts and a few sample images per label.

# %%
import os, json
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image

if not Path('datasets_report.json').exists():
    print('datasets_report.json not found — run dry-run/report-only cell first')
else:
    report = json.load(open('datasets_report.json'))
    print('Label summary:')
    for label, info in report.get('labels', {}).items():
        print(f"- {label}: {info.get('image_count','?')} images, texts: {info.get('text_count','?')}")
    # Show sample images for first label
    sample_label = next(iter(report.get('labels', {})), None)
    if sample_label:
        roots = report['labels'][sample_label].get('image_roots', [])
        if roots:
            img_files = list(Path(roots[0]).rglob('*.jpg'))[:9]
            if img_files:
                fig, axs = plt.subplots(1, len(img_files), figsize=(3*len(img_files),3))
                for ax, p in zip(axs, img_files):
                    ax.imshow(Image.open(p).convert('RGB'))
                    ax.axis('off')
                plt.show()
            else:
                print('No images found under', roots[0])

# %% [markdown]
# ## 8) Troubleshooting & common fixes ⚠️
#
# - Kaggle 401/403: ensure `kaggle.json` is correct and competitions are accepted via `https://www.kaggle.com/` (some datasets require acceptance).\n- If a dataset fails on Kaggle, the script tries HTTP/GitHub fallbacks and will synthesize small datasets when absolutely necessary.\n- Check `datasets_report.json` and `local_datasets_report.json` for detailed diagnostics.
#
# If you hit a persistent issue, paste the relevant log output (error lines) into the project's GitHub issue or ask here for help.

# %% [markdown]
# ## Final notes & next steps ✅
#
# 1. Start with the **dry-run** cell and inspect `datasets_report.json`.
# 2. If the dataset preview looks good, run **download-only**. Expect Kaggle prompts/acceptance for some datasets.
# 3. Run quick smoke training before committing to longer training runs. Adjust script config to small epochs / samples.
# 4. If you want, I can run the dry-run in a Colab session for you (requires permission to execute). Ask and I'll proceed.
#
# Good luck — run step-by-step and paste any errors here if you want me to help debug them. 🔧

# %% [markdown]
# ## Before you run (Important) ⚠️
#
# This notebook will *only* run commands you execute manually. Follow these steps:
#
# 1. Run the **Credentials** cell and upload `kaggle.json` when prompted (or set `KAGGLE_USERNAME` / `KAGGLE_KEY` env vars). ✅
# 2. Paste your HuggingFace token when asked (optional but recommended). ✅
# 3. Run the **Dry-run** cell to preview dataset acquisition and inspect `datasets_report.json`. ✅
# 4. If the dry-run looks OK and you want to fetch *real* datasets, run the **Download datasets** cell. This will ask you to confirm `--allow-synthesis` usage (I recommend `NO` for now so only real datasets are used). ⬇️
#
# _Note: I will not run anything automatically — you must execute each cell manually._

# %%
# Set whether synthesis is allowed for missing labels (default: NO)
allow = input('Allow synthesis for missing image labels? (y/N): ').strip().lower()
import os
if allow in ('y','yes'):
    os.environ['ALLOW_SYNTHESIS'] = '1'
    print('ALLOW_SYNTHESIS set to 1')
else:
    os.environ.pop('ALLOW_SYNTHESIS', None)
    print('ALLOW_SYNTHESIS unset (will require real datasets)')

# %%
## Dry-run (preview datasets) 🔍

Run this cell to preview what will be downloaded / found. It will create `datasets_report.json` but will not download large files.

# Dry-run: preview (no network actions if your script honors --dry-run)
# !python FarmFederate_Kaggle_Complete.py --dry-run --report-only

# After running, inspect generated reports
import json, os
if os.path.exists('datasets_report.json'):
    print('\n=== datasets_report.json preview ===')
    print(json.dumps(json.load(open('datasets_report.json')), indent=2)[:1000])
else:
    print('\nNo datasets_report.json found — check the script output for errors')

# %%
## Upload `kaggle.json` and set HuggingFace token 🔐

# Upload kaggle.json and set it up (one-time)
from google.colab import files
print('Upload kaggle.json when prompted (https://www.kaggle.com/me/account)')
uploaded = files.upload()
if 'kaggle.json' in uploaded:
    import os
    os.makedirs('/root/.kaggle', exist_ok=True)
    open('/root/.kaggle/kaggle.json','wb').write(uploaded['kaggle.json'])
    os.chmod('/root/.kaggle/kaggle.json', 0o600)
    print('kaggle.json saved to /root/.kaggle/kaggle.json')
else:
    print('kaggle.json not uploaded; you can still use HTTP/GitHub fallbacks')

# Set HF token interactively (recommended)
try:
    hf = input('Paste your HuggingFace token (or leave blank to skip): ').strip()
    if hf:
        import os
        os.environ['HF_TOKEN'] = hf
        print('HF_TOKEN set in environment for this session')
except Exception as e:
    print('Skipping HF token setup:', e)

# %%
## Download datasets (requires `kaggle.json` / accepted competitions) ⬇️

# Run this only AFTER you uploaded kaggle.json and reviewed the dry-run.
confirm = input('Proceed with dataset download now? This will attempt Kaggle downloads. (yes/NO): ').strip().lower()
if confirm in ('y','yes'):
    allow = os.environ.get('ALLOW_SYNTHESIS','0')
    cmd = 'python FarmFederate_Kaggle_Complete.py --download-only'
    if allow == '1':
        cmd += ' --allow-synthesis'
    print('Running:', cmd)
    # !{cmd}
    print('\nAfter download, run the scanner:')
    # !python scripts/check_datasets.py || true
    if os.path.exists('local_datasets_report.json'):
        import json
        print(json.dumps(json.load(open('local_datasets_report.json')), indent=2)[:1000])
else:
    print('Download cancelled by user')

# %%
## Quick smoke training (short run) 🏃‍♂️

# Use minimal settings for a fast sanity check — edit parameters below as needed
q = input('Run quick training now? (yes/NO): ').strip().lower()
if q in ('y','yes'):
    import os
    os.environ['QUICK_TRAIN'] = '1'
    print('Starting quick train (1 epoch, small sample sizes) — this will take a few minutes')
    # !python FarmFederate_Kaggle_Complete.py --train-quick || true
else:
    print('Quick training skipped')
